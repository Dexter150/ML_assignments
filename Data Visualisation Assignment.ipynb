# %% [markdown]
# **Problem Statement : In this assignment students have to transform iris data into 3 dimensions and plot a 3d chart with transformed dimensions and colour each data point with specific class.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets
import pandas as pd

# %%
iris = datasets.load_iris()
df=pd.DataFrame(iris.data)
df['class']=iris.target
df.columns=['sepal-len', 'sepal-wid', 'petal-len', 'petal-wid', 'class']

# %%
df.head()
# Out:
#    sepal-len  sepal-wid  petal-len  petal-wid  class
# 0        5.1        3.5        1.4        0.2      0
# 1        4.9        3.0        1.4        0.2      0
# 2        4.7        3.2        1.3        0.2      0
# 3        4.6        3.1        1.5        0.2      0
# 4        5.0        3.6        1.4        0.2      0

# %%
x = df.iloc[:,0:4]
y=df.iloc[:,4]

# %%
x.head()
# Out:
#    sepal-len  sepal-wid  petal-len  petal-wid
# 0        5.1        3.5        1.4        0.2
# 1        4.9        3.0        1.4        0.2
# 2        4.7        3.2        1.3        0.2
# 3        4.6        3.1        1.5        0.2
# 4        5.0        3.6        1.4        0.2

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: class, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
print(x[:10])
# Out:
# [[-0.90068117  1.01900435 -1.34022653 -1.3154443 ]
#  [-1.14301691 -0.13197948 -1.34022653 -1.3154443 ]
#  [-1.38535265  0.32841405 -1.39706395 -1.3154443 ]
#  [-1.50652052  0.09821729 -1.2833891  -1.3154443 ]
#  [-1.02184904  1.24920112 -1.34022653 -1.3154443 ]
#  [-0.53717756  1.93979142 -1.16971425 -1.05217993]
#  [-1.50652052  0.78880759 -1.34022653 -1.18381211]
#  [-1.02184904  0.78880759 -1.2833891  -1.3154443 ]
#  [-1.74885626 -0.36217625 -1.34022653 -1.3154443 ]
#  [-1.14301691  0.09821729 -1.2833891  -1.44707648]]

# %%
# Reducing 4-D to 3-D 
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
x = pca.fit_transform(x)
x[:10]
# Out:
# array([[-2.26470281,  0.4800266 , -0.12770602],
#        [-2.08096115, -0.67413356, -0.23460885],
#        [-2.36422905, -0.34190802,  0.04420148],
#        [-2.29938422, -0.59739451,  0.09129011],
#        [-2.38984217,  0.64683538,  0.0157382 ],
#        [-2.07563095,  1.48917752,  0.02696829],
#        [-2.44402884,  0.0476442 ,  0.3354704 ],
#        [-2.23284716,  0.22314807, -0.0886955 ],
#        [-2.33464048, -1.11532768,  0.14507686],
#        [-2.18432817, -0.46901356, -0.25376557]])

# %%
fig = plt.figure(1, figsize=(12,10))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
plt.cla()
# Reorder the labels to have colors matching the cluster results
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, edgecolor='b')
plt.show()
